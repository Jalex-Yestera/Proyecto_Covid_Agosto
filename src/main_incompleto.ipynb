# %% [markdown]
# # Archivo jupyter del grupo B con las llamadas a las funciones necesarias para el análisis de nuestros países. @CristiDatas

# %% [markdown]
# # MINING

# %%
# Añadimos al sys.path la ruta de la carpeta utils para que se puedan importar los módulos: @CristiDatas

import sys
sys.path.append("../src/utils")

# %%
# Importamos bibliotecas:  @CristiDatas

import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import folders_tb as fd
import mining_data_tb as mng
import visualization_tb as vsn

# %%
# Función open_csv de folders_tb para abrir el dataset. Convertimos el csv en dataframe csv_df y establecemos que "date" es tipo fecha:  @CristiDatas

csv_df=fd.open_csv(url="https://covid.ourworldindata.org/data/owid-covid-data.csv")

# %%
# Función seleccion_paises de mining_data para seleccionar los países a analizar por nuestro grupo:  @CristiDatas

df=mng.seleccion_paises(dataframe=csv_df,paises=["India","Peru","United States","France","Spain"])
df.shape
# Out:
# (1110, 39)

# %%
# Función borrar_previo de mining_data para buscar cuándo fue el primer caso y borrar las fechas anteriores. Se actualizará en cada carga.  @CristiDatas

df=mng.borrar_previo(dataframe=df)
df.shape
# Out:
# (1026, 39)

# %%
# Estudiamos las columnas para saber las que nos interesan:  @CristiDatas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1026 entries, 2020-01-21 to 2020-08-20
# Data columns (total 39 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         1026 non-null   object
#  1   continent                        1026 non-null   object
#  2   location                         1026 non-null   object
#  3   total_cases                      1016 non-null   float64
#  4   new_cases                        1016 non-null   float64
#  5   new_cases_smoothed               1012 non-null   float64
#  6   total_deaths                     1016 non-null   float64
#  7   new_deaths                       1016 non-null   float64
#  8   new_deaths_smoothed              1012 non-null   float64
#  9   total_cases_per_million          1016 non-null   float64
#  10  new_cases_per_million            1016 non-null   float64
# ...

# %%
# Función seleccion_columnas de mining_data para seleccionar las columnas a analizar:  @CristiDatas

df=mng.seleccion_columnas(dataframe=df,col1=2,col2=15)

# %%
# Función cero_nan de mining_data para cambiar los valores Nan por ceros:  @CristiDatas
df=mng.cero_nan(dataframe=df)

# %%
# Función paises_juntos de visualization_tb para comparar la evolución a lo largo del tiempo de cada columna en todos los países del grupo a la vez. Primero hace una pivot table de cada columna (mediante un for), luego muestra cada gráfico y por último los guarda como archivos en la carpeta paises_juntos, de plots, dentro de resources. Cada vez que se ejecuta sobreescribe el archivo para actualizar. @CristiDatas

vsn.paises_juntos(dataframe=df)
# Out:
#  total_cases
#  new_cases
#  new_cases_smoothed
#  total_deaths
#  new_deaths
#  new_deaths_smoothed
#  total_cases_per_million
#  new_cases_per_million
#  new_cases_smoothed_per_million
#  total_deaths_per_million
#  new_deaths_per_million
#  new_deaths_smoothed_per_million
#  total_cases
#
#
#  new_cases
#
#
#  new_cases_smoothed
#
#
#  total_deaths
#
#
#  new_deaths
#
#
#  new_deaths_smoothed
#
#
#  total_cases_per_million
#
#
#  new_cases_per_million
#
#
#  new_cases_smoothed_per_million
#
#
#  total_deaths_per_million
#
#
#  new_deaths_per_million
#
#
#  new_deaths_smoothed_per_million
